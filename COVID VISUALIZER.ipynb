# %%
import pandas as pd                                                  #Importem la llibreria pandas (pd).
import geopandas as gpd
dades = pd.read_csv('time_series_covid19_deaths_US.csv')  
                                   
dades = pd.DataFrame(dades)  

dades
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-33e87eadf31d> in <module>
#       1 import pandas as pd                                                  #Importem la llibreria pandas (pd).
# ----> 2 import geopandas as gpd
#       3 dades = pd.read_csv('time_series_covid19_deaths_US.csv')
#       4
#       5 dades = pd.DataFrame(dades)
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
dades = dades.drop(columns = ["UID", "iso2", "iso3", "code3", "FIPS", "Country_Region", "Population", "Combined_Key"])

# %%
dades
# Out:
#           Admin2 Province_State        Lat       Long_  1/22/20  1/23/20  \
# 0        Autauga        Alabama  32.539527  -86.644082        0        0
# 1        Baldwin        Alabama  30.727750  -87.722071        0        0
# 2        Barbour        Alabama  31.868263  -85.387129        0        0
# 3           Bibb        Alabama  32.996421  -87.125115        0        0
# 4         Blount        Alabama  33.982109  -86.567906        0        0
# ...          ...            ...        ...         ...      ...      ...
# 3335       Teton        Wyoming  43.935225 -110.589080        0        0
# 3336       Uinta        Wyoming  41.287818 -110.547578        0        0
# 3337  Unassigned        Wyoming   0.000000    0.000000        0        0
# 3338    Washakie        Wyoming  43.904516 -107.680187        0        0
# 3339      Weston        Wyoming  43.839612 -104.567488        0        0
#
#       1/24/20  1/25/20  1/26/20  1/27/20  ...  10/7/20  10/8/20  10/9/20  \
# 0           0        0        0        0  ...       27       28       28
# 1           0        0        0        0  ...       56       64       64
# 2           0        0        0        0  ...        7        9        9
# 3           0        0        0        0  ...       10       12       12
# 4           0        0        0        0  ...       16       16       16
# ...       ...      ...      ...      ...  ...      ...      ...      ...
# 3335        0        0        0        0  ...        1        1        1
# 3336        0        0        0        0  ...        2        2        2
# 3337        0        0        0        0  ...        0        1        1
# 3338        0        0        0        0  ...        6        6        6
# 3339        0        0        0        0  ...        0        0        0
#
#       10/10/20  10/11/20  10/12/20  10/13/20  10/14/20  10/15/20  10/16/20
# 0           28        28        28        28        28        28        28
# 1           65        65        65        65        66        66        67
# 2            9         9         9         9         9         9         9
# 3           12        12        12        12        13        13        13
# 4           16        16        16        16        23        23        23
# ...        ...       ...       ...       ...       ...       ...       ...
# 3335         1         1         1         1         1         1         1
# 3336         2         2         2         2         2         2         2
# 3337         1         1         0         0         0         0         0
# 3338         6         6         6         7         7         7         7
# 3339         0         0         0         0         0         0         0
#
# [3340 rows x 273 columns]

# %%
USA=gpd.read('Usa_counties_large.svg')
USA

# %%
# import pygame
import pygame

# initialize game engine
pygame.init()

window_width=1276
window_height=685

animation_increment=10
clock_tick_rate=20

# Open a window
size = (window_width, window_height)
screen = pygame.display.set_mode(size)

# Set title to the window
pygame.display.set_caption("Hello World")

dead=False

clock = pygame.time.Clock()
background_image = pygame.image.load("q0nNoWgj-WrSUvKGuaFAbt9IGoFbThlVUYhyioQtrgs.png").convert()

while(dead==False):
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            dead = True

    screen.blit(background_image, [0, 0])

    pygame.display.flip()
    clock.tick(clock_tick_rate)

# %%
pygame.quit()

# %%
# Out:
# Què ha fet el scale??? [[ 1.6062199   1.65078218  0.29700938 ...  0.83804241 -0.27196975
#    0.78352786]
#  [-1.17733465 -1.0970492  -1.59073643 ... -0.31824547 -0.68711913
#    0.18167492]
#  [-0.25407645 -0.35252506  0.85272781 ...  0.30478211 -1.92993406
#   -2.7487145 ]
#  ...
#  [-0.71915054 -0.90516153  1.07756046 ...  0.14768939 -0.347044
#   -2.74881166]
#  [ 0.01118803  0.00822376  0.42851527 ...  0.3379105  -1.36110658
#    0.08108031]
#  [-1.35647429 -1.35034092 -1.43377779 ... -0.36526641  0.40986128
#    0.08108031]]
#             0         1
# 0   -2.529202 -0.482049
# 1    1.786400  0.343861
# 2    0.680146  2.983871
# 3   -2.441345 -0.014529
# 4   -2.352889 -0.357016
# ..        ...       ...
# 205 -0.411076 -0.664940
# 206 -0.623649 -0.707090
# 207  0.805643  0.265908
# 208 -0.685007  0.894754
# 209  2.241903 -0.318529
#
# [210 rows x 2 columns]
# creem una Y: 84     2
# 146    3
# 7      1
# 105    2
# 92     2
#       ..
# 132    2
# 134    2
# 199    3
# 1      1
# 187    3
# Name: seed, Length: 210, dtype: int64
# Y nova: 0      2
# 1      3
# 2      1
# 3      2
# 4      2
#       ..
# 205    2
# 206    2
# 207    3
# 208    1
# 209    3
# Name: seed, Length: 210, dtype: int64
#             0         1  seed
# 0   -2.529202 -0.482049     2
# 1    1.786400  0.343861     3
# 2    0.680146  2.983871     1
# 3   -2.441345 -0.014529     2
# 4   -2.352889 -0.357016     2
# ..        ...       ...   ...
# 205 -0.411076 -0.664940     2
# 206 -0.623649 -0.707090     2
# 207  0.805643  0.265908     3
# 208 -0.685007  0.894754     1
# 209  2.241903 -0.318529     3
#
# [210 rows x 3 columns]

# %%
# Out:
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# 'c' argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with 'x' & 'y'.  Please use a 2-D array with a single row if you really want to specify the same RGB or RGBA value for all points.
# [[0.12156863 0.46666667 0.70588235 1.        ]
#  [0.54901961 0.3372549  0.29411765 1.        ]
#  [0.61960784 0.85490196 0.89803922 1.        ]]
